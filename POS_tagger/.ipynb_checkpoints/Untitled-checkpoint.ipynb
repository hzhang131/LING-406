# %%
# Import statements
import string
import numpy as np
import pandas as pd
import csv
from sklearn.dummy import DummyClassifier
from sklearn.model_selection import KFold
from sklearn.naive_bayes import GaussianNB
from sklearn.tree import DecisionTreeClassifier
from sklearn.datasets import fetch_20newsgroups
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics import f1_score, precision_score, recall_score
from sklearn.preprocessing import OneHotEncoder, LabelEncoder
from sklearn.feature_extraction import DictVectorizer

# %%
df = pd.read_csv('pos-eng-5000.data.csv')
size = df.shape
cols = df.columns
df.head()
v = DictVectorizer()
stc_dict = df[['a1', 'a2', 'a3', 'a4', 'a5', 'a6', 'a7']].to_dict('records')
class_dict = df[['class']].to_dict('records')

stc_res = v.fit_transform(stc_dict)
class_res = v.fit_transform(class_dict)
print(class_res)
# Out:
#   (0, 8)	1.0
#   (1, 16)	1.0
#   (2, 37)	1.0
#   (3, 12)	1.0
#   (4, 21)	1.0
#   (5, 8)	1.0
#   (6, 19)	1.0
#   (7, 33)	1.0
#   (8, 11)	1.0
#   (9, 9)	1.0
#   (10, 15)	1.0
#   (11, 25)	1.0
#   (12, 32)	1.0
#   (13, 8)	1.0
#   (14, 16)	1.0
#   (15, 11)	1.0
#   (16, 19)	1.0
#   (17, 11)	1.0
#   (18, 8)	1.0
#   (19, 16)	1.0
#   (20, 22)	1.0
#   (21, 12)	1.0
#   (22, 12)	1.0
#   (23, 16)	1.0
#   (24, 37)	1.0
#   :	:
#   (4975, 16)	1.0
#   (4976, 2)	1.0
#   (4977, 16)	1.0
#   (4978, 5)	1.0
#   (4979, 7)	1.0
#   (4980, 8)	1.0
#   (4981, 12)	1.0
#   (4982, 16)	1.0
#   (4983, 33)	1.0
#   (4984, 21)	1.0
#   (4985, 8)	1.0
#   (4986, 16)	1.0
#   (4987, 33)	1.0
#   (4988, 11)	1.0
#   (4989, 23)	1.0
#   (4990, 33)	1.0
#   (4991, 11)	1.0
#   (4992, 16)	1.0
#   (4993, 30)	1.0
#   (4994, 16)	1.0
#   (4995, 11)	1.0
#   (4996, 8)	1.0
#   (4997, 16)	1.0
#   (4998, 21)	1.0
#   (4999, 23)	1.0

# %%
df = pd.read_csv('pos-eng-5000.data.csv')
size = df.shape
cols = df.columns
v = LabelEncoder()
df.apply(LabelEncoder().fit_transform)
# Out:
#         a1    a2    a3    a4    a5    a6    a7  class
# 0      524   551   584   524   681  1477   649      8
# 1      524   551   524   763  1556   677   333     16
# 2      524   493   764  1638   725   347   440     37
# 3      469   721  1639   807   373   461   440     12
# 4      689  1533   808   430   501   461   440     21
# ...    ...   ...   ...   ...   ...   ...   ...    ...
# 4995  1558  1770  1735  1224   503   956   333     11
# 4996  1698  1624  1225   585  1017   347   440      8
# 4997  1558  1139   586  1099   373   461   440     16
# 4998  1092   553  1100   430   501   461   440     21
# 4999   524   551   584   307   866  1533  1657     23
#
# [5000 rows x 8 columns]

# %%
df = pd.read_csv('pos-eng-5000.data.csv')
v = LabelEncoder()
everything = df[['a1', 'a2', 'a3', 'a4', 'a5', 'a6', 'a7']].to_numpy()
word_list = []
for row in everything:
    for word in row:
        if word not in word_list:
            word_list.append(word)
word_code = v.fit_transform(word_list)
word_inverted = v.inverse_transform(word_code)

print(word_inverted)
print(word_code)

word_code_dict = {}
for i in range(len(word_inverted)):
    word_code_dict[word_inverted[i]] = word_code[i]
# Out:
# ['_' 'The' 'cafeteria' ... 'side' 'frenzy' 'seem']
# [ 584  524  764 ... 1736 1100 1696]

# %%
everything = df[['a1', 'a2', 'a3', 'a4', 'a5', 'a6', 'a7']].to_numpy()
# print(everything)
grand_list = []
for row in everything:
    local_list = []
    for i in row:
        local_list.append(word_code_dict.get(i))
    grand_list.append(local_list)

for row in grand_list:
    print(row)
# Out:
# [[584, 584, 584, 524, 764, 1639, 808], [584, 584, 524, 764, 1639, 808, 430], [584, 524, 764, 1639, 808, 430, 584], [524, 764, 1639, 808, 430, 584, 584], [764, 1639, 808, 430, 584, 584, 584], [584, 584, 584, 504, 641, 663, 1863], [584, 584, 504, 641, 663, 1863, 1869], [584, 504, 641, 663, 1863, 1869, 2011], [504, 641, 663, 1863, 1869, 2011, 1411], [641, 663, 1863, 1869, 2011, 1411, 691], [663, 1863, 1869, 2011, 1411, 691, 586], [1863, 1869, 2011, 1411, 691, 586, 1083], [1869, 2011, 1411, 691, 586, 1083, 1447], [2011, 1411, 691, 586, 1083, 1447, 1841], [1411, 691, 586, 1083, 1447, 1841, 694], [691, 586, 1083, 1447, 1841, 694, 1864], [586, 1083, 1447, 1841, 694, 1864, 1235], [1083, 1447, 1841, 694, 1864, 1235, 481], [1447, 1841, 694, 1864, 1235, 481, 854], [1841, 694, 1864, 1235, 481, 854, 773], [694, 1864, 1235, 481, 854, 773, 1570], [1864, 1235, 481, 854, 773, 1570, 1264], [1235, 481, 854, 773, 1570, 1264, 975], [481, 854, 773, 1570, 1264, 975, 1956], [854, 773, 1570, 1264, 975, 1956, 680], [773, 1570, 1264, 975, 1956, 680, 778], [1570, 1264, 975, 1956, 680, 778, 430], [1264, 975, 1956, 680, 778, 430, 584], [975, 1956, 680, 778, 430, 584, 584], [1956, 680, 778, 430, 584, 584, 584], [584, 584, 584, 103, 1442, 1447, 927], [584, 584, 103, 1442, 1447, 927, 1991], [584, 103, 1442, 1447, 927, 1991, 1422], [103, 1442, 1447, 927, 1991, 1422, 1251], [1442, 1447, 927, 1991, 1422, 1251, 761], [1447, 927, 1991, 1422, 1251, 761, 1904], [927, 1991, 1422, 1251, 761, 1904, 430], [1991, 1422, 1251, 761, 1904, 430, 584], [1422, 1251, 761, 1904, 430, 584, 584], [1251, 761, 1904, 430, 584, 584, 584], [584, 584, 584, 524, 1525, 1753, 1447], [584, 584, 524, 1525, 1753, 1447, 1758], [584, 524, 1525, 1753, 1447, 1758, 1285], [524, 1525, 1753, 1447, 1758, 1285, 1447], [1525, 1753,